# %%
import numpy as np
from sklearn.manifold import TSNE
import torch
from transformers import BertConfig, BertModel, BertTokenizer
from transformers import BertForMaskedLM, BertTokenizerFast, pipeline
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from umap import UMAP

# %%
config = BertConfig.from_json_file("config.json")
model = BertForMaskedLM.from_pretrained('/home/customer/hyr/matbert-uncased（copy-version）')
tokenizer = BertTokenizerFast.from_pretrained('/home/customer/hyr/matbert-uncased（copy-version）', do_lower_case=False)
# unmasker = pipeline('fill-mask', model=model, tokenizer=tokenizer)

# %%
# # 提取所有词向量
# all_word_embeddings = []
# for word in tokenizer.vocab.keys():
#     if word.isalnum():  # 只选择字母数字组合的词，排除特殊标记
#         token_id = tokenizer.encode(word, add_special_tokens=False)
#         if len(token_id) == 1:  # 确保词没有分词成多个子词
#             token_id = torch.tensor(token_id).unsqueeze(0)
#             embeddings = model.bert.embeddings.word_embeddings(token_id)
#             all_word_embeddings.append(embeddings.squeeze().detach().numpy())

# all_word_embeddings = np.array(all_word_embeddings)

# %%
# from umap import UMAP
# # 使用UMAP进行降维
# reducer = UMAP()
# embeddings_umap = reducer.fit_transform(all_word_embeddings)

# %%
# # 可视化降维后的词向量
# plt.figure(figsize=(10, 8))
# plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], s=10)
# plt.title('UMAP Visualization of BERT Word Embeddings')
# plt.xlabel('UMAP Dimension 1')
# plt.ylabel('UMAP Dimension 2')
# plt.show()

# %%
# ----------------------------------------------------------

# %%
# 提取所有词向量
all_word_embeddings = []
all_words = []
for word in tokenizer.vocab.keys():
    if word.isalnum():  # 只选择字母数字组合的词，排除特殊标记
        token_id = tokenizer.encode(word, add_special_tokens=False)
        if len(token_id) == 1:  # 确保词没有分词成多个子词
            token_id = torch.tensor(token_id).unsqueeze(0)
            embeddings = model.bert.embeddings.word_embeddings(token_id)
            all_word_embeddings.append(embeddings.squeeze().detach().numpy())
            all_words.append(word)

all_word_embeddings = np.array(all_word_embeddings)

# %%
from umap import UMAP
# 使用UMAP进行降维
reducer = UMAP()
embeddings_umap = reducer.fit_transform(all_word_embeddings)

# %%
# 可视化降维后的词向量
plt.figure(figsize=(10, 8))
for i in range(len(all_words)):
    plt.scatter(embeddings_umap[i, 0], embeddings_umap[i, 1], color='gray', s=5)

# 标记高亮词汇
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='blue', s=20)
        plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='blue')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %%
highlighted_words = ['perovskite','mapbi3','lamno3','batio3']
# 可视化降维后的词向量
plt.figure(figsize=(10, 8))
for i in range(len(all_words)):
    plt.scatter(embeddings_umap[i, 0], embeddings_umap[i, 1], color='gray', s=20)

# 标记高亮词汇
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='blue', s=20)
        plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='blue')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.savefig('allword_highlight.png')
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
# 计算所有词向量与"perovskite"的余弦相似度
perovskite_token = tokenizer.encode("perovskite", add_special_tokens=False)
perovskite_embedding = model.bert.embeddings.word_embeddings(torch.tensor(perovskite_token)).squeeze().detach().numpy()
cos_similarities = cosine_similarity(all_word_embeddings, [perovskite_embedding])

# %%
# 可视化降维后的词向量，并根据余弦相似度调整颜色深浅
plt.figure(figsize=(10, 8))
cmap = plt.cm.BuPu
scatter=plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=cos_similarities.squeeze(), cmap=cmap, s=20)

# 标记高亮词汇
highlighted_words = ["perovskite", "lamno3"]
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='red', marker='*', s=100)
        plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='red')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# 添加颜色条
cbar = plt.colorbar(scatter)
cbar.set_label('Cosine Similarity')

# 设置颜色条的范围，使其只显示蓝色部分
cbar.set_ticks(np.linspace(0, 1, 6))

# plt.axis([-50, 50, -60, 60])




plt.savefig("word_embeddings_visualization.png")
plt.show()

# %%
# 可视化降维后的词向量，并根据余弦相似度调整颜色深浅
plt.figure(figsize=(10, 8))

# plt.cm.Blues: 蓝色调色板
# plt.cm.Greens: 绿色调色板
# plt.cm.Reds: 红色调色板
# plt.cm.Oranges: 橙色调色板
# plt.cm.Purples: 紫色调色板
# plt.cm.Greys: 灰色调色板
# plt.cm.YlOrBr: 黄橙棕色调色板
# plt.cm.YlOrRd: 黄橙红色调色板
# marker='o',marker='s'marker='^'、marker='v'、marker='<'、marker='>' marker='+'marker='x'
cmap = plt.cm.BuPu
scatter=plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=cos_similarities.squeeze(), cmap=cmap, s=20)

# 标记高亮词汇
highlighted_words = ["perovskite", "lamno3"]
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='red', marker='*',s=50)
        # plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='red')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# 添加颜色条
cbar = plt.colorbar(scatter)
cbar.set_label('Cosine Similarity')

# 设置颜色条的范围，使其只显示蓝色部分
cbar.set_ticks(np.linspace(0, 1, 6))

# plt.axis([-50, 50, -60, 60])

plt.savefig("word_embeddings_visualization.png")
plt.show()

# %%
 # 目标词汇1
word3_token = tokenizer.encode("perovskite", add_special_tokens=False)
word3_embedding = model.bert.embeddings.word_embeddings(torch.tensor(word3_token)).squeeze().detach().numpy()
cos_word3 = cosine_similarity(all_word_embeddings, [word3_embedding])
 # 目标词汇2
word4_token = tokenizer.encode("stable", add_special_tokens=False)
word4_embedding = model.bert.embeddings.word_embeddings(torch.tensor(word4_token)).squeeze().detach().numpy()
cos_word4 = cosine_similarity(all_word_embeddings, [stable_embedding])

# %%
plt.figure(figsize=(10, 8))
# 先绘制灰色的点
gray_indices = [i for i in range(len(all_words)) if cos_word3[i] <= 0.4 and cos_word4[i] <= 0.4]
gray_embeddings_umap = embeddings_umap[gray_indices]
plt.scatter(gray_embeddings_umap[:, 0], gray_embeddings_umap[:, 1], color='gray', s=20)

# 再绘制高亮的点
highlighted_indices = [i for i in range(len(all_words)) if i not in gray_indices]
highlighted_embeddings_umap = embeddings_umap[highlighted_indices]
highlighted_colors = ['blue' if cos_word3[i] > 0.4 else 'green' for i in highlighted_indices]
plt.scatter(highlighted_embeddings_umap[:, 0], highlighted_embeddings_umap[:, 1], c=highlighted_colors, s=20)

# # 标记高亮词汇
# highlighted_words = ["perovskite", "lamno3", "stable"]
# highlighted_colors = ['blue', 'red', 'green']
# for word, color in zip(highlighted_words, highlighted_colors):
#     if word in all_words:
#         idx = all_words.index(word)
#         plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color=color, s=20)
#         plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color=color)

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.savefig("word_embeddings_visualization.png")
plt.show()

# %%
# 定义要比较的词
target_word1 = "htl"
# 计算目标词与所有其他词的余弦相似度
target_token_id = tokenizer.encode(target_word1, add_special_tokens=False)
target_embedding = model.bert.embeddings.word_embeddings(torch.tensor(target_token_id)).squeeze().detach().numpy()
cos_similarities2 = cosine_similarity(all_word_embeddings, [target_embedding])
# 对相似度进行排序并获取排序后的索引
sorted_indices = np.argsort(cos_similarities2.flatten())[::-1]

# 打印排名和相似度
print("cosine similarity for '{}':".format(target_word1))
for rank, idx in enumerate(sorted_indices):
    word = all_words[idx]
    similarity = cos_similarities2[idx][0]
    print("{}: {} (Cosine Similarity: {:.4f})".format(rank + 1, word, similarity))
# Out:
# cosine similarity for 'htl':
# 1: htl (Cosine Similarity: 1.0000)
# 2: etl (Cosine Similarity: 0.5385)
# 3: htm (Cosine Similarity: 0.4725)
# 4: htc (Cosine Similarity: 0.4686)
# 5: dewatering (Cosine Similarity: 0.4682)
# 6: 371 (Cosine Similarity: 0.4509)
# 7: hydrotalcite (Cosine Similarity: 0.4470)
# 8: npb (Cosine Similarity: 0.4468)
# 9: dewater (Cosine Similarity: 0.4440)
# 10: blad (Cosine Similarity: 0.4422)
# 11: hhv (Cosine Similarity: 0.4405)
# 12: calcining (Cosine Similarity: 0.4393)
# 13: mpl (Cosine Similarity: 0.4374)
# 14: 379 (Cosine Similarity: 0.4366)
# 15: ctl (Cosine Similarity: 0.4355)
# 16: interlayers (Cosine Similarity: 0.4323)
# 17: lsmo (Cosine Similarity: 0.4313)
# 18: jatropha (Cosine Similarity: 0.4292)
# 19: biorefinery (Cosine Similarity: 0.4287)
# 20: oled (Cosine Similarity: 0.4259)
# 21: mapbi3 (Cosine Similarity: 0.4247)
# 22: bioref (Cosine Similarity: 0.4245)
# 23: teph (Cosine Similarity: 0.4238)
# 24: commercialization (Cosine Similarity: 0.4214)
# 25: heterocyc (Cosine Similarity: 0.4211)
# 26: liquefaction (Cosine Similarity: 0.4210)
# 27: 378 (Cosine Similarity: 0.4204)
# 28: 377 (Cosine Similarity: 0.4202)
# 29: dehydroxylation (Cosine Similarity: 0.4191)
# 30: dabco (Cosine Similarity: 0.4164)
# 31: alkylated (Cosine Similarity: 0.4161)
# 32: myeloid (Cosine Similarity: 0.4155)
# 33: toled (Cosine Similarity: 0.4143)
# 34: ℛ (Cosine Similarity: 0.4141)
# 35: nanofiltration (Cosine Similarity: 0.4138)
# 36: transporters (Cosine Similarity: 0.4136)
# 37: pretreat (Cosine Similarity: 0.4136)
# 38: bhj (Cosine Similarity: 0.4131)
# 39: torrefaction (Cosine Similarity: 0.4122)
# 40: lpe (Cosine Similarity: 0.4122)
# 41: photosensitizers (Cosine Similarity: 0.4119)
# 42: hydrolysate (Cosine Similarity: 0.4115)
# 43: obese (Cosine Similarity: 0.4110)
# 44: photoanodes (Cosine Similarity: 0.4110)
# 45: 770 (Cosine Similarity: 0.4110)
# 46: jat (Cosine Similarity: 0.4106)
# 47: 326 (Cosine Similarity: 0.4104)
# 48: upgrad (Cosine Similarity: 0.4100)
# 49: 444 (Cosine Similarity: 0.4099)
# 50: periph (Cosine Similarity: 0.4097)
# 51: mqw (Cosine Similarity: 0.4090)
# 52: nitrification (Cosine Similarity: 0.4087)
# 53: terrigenous (Cosine Similarity: 0.4083)
# 54: ch3nh3pbi3 (Cosine Similarity: 0.4081)
# 55: opin (Cosine Similarity: 0.4079)
# 56: 375 (Cosine Similarity: 0.4078)
# 57: pepti (Cosine Similarity: 0.4078)
# 58: luo (Cosine Similarity: 0.4077)
# 59: volatilization (Cosine Similarity: 0.4077)
# 60: 381 (Cosine Similarity: 0.4071)
# 61: zn0 (Cosine Similarity: 0.4068)
# 62: organocl (Cosine Similarity: 0.4068)
# 63: tfts (Cosine Similarity: 0.4063)
# 64: pubmed (Cosine Similarity: 0.4063)
# 65: eclog (Cosine Similarity: 0.4060)
# 66: photolith (Cosine Similarity: 0.4059)
# 67: infeas (Cosine Similarity: 0.4058)
# 68: lto (Cosine Similarity: 0.4057)
# 69: scw (Cosine Similarity: 0.4051)
# 70: coagulant (Cosine Similarity: 0.4049)
# 71: biobr (Cosine Similarity: 0.4048)
# 72: feedstocks (Cosine Similarity: 0.4048)
# 73: 453 (Cosine Similarity: 0.4046)
# 74: λl (Cosine Similarity: 0.4046)
# 75: amphoter (Cosine Similarity: 0.4046)
# 76: benef (Cosine Similarity: 0.4045)
# 77: 1017 (Cosine Similarity: 0.4043)
# 78: dihydrox (Cosine Similarity: 0.4039)
# 79: photoanode (Cosine Similarity: 0.4036)
# 80: hydrolysates (Cosine Similarity: 0.4027)
# 81: pillared (Cosine Similarity: 0.4023)
# 82: 443 (Cosine Similarity: 0.4021)
# 83: 890 (Cosine Similarity: 0.4019)
# 84: 445 (Cosine Similarity: 0.4017)
# 85: 374 (Cosine Similarity: 0.4014)
# 86: hydrothermally (Cosine Similarity: 0.4013)
# 87: concentr (Cosine Similarity: 0.4006)
# 88: hil (Cosine Similarity: 0.4000)
# 89: transester (Cosine Similarity: 0.4000)
# 90: aliqu (Cosine Similarity: 0.4000)
# 91: saccharification (Cosine Similarity: 0.4000)
# 92: pyrolyzed (Cosine Similarity: 0.3999)
# 93: 436 (Cosine Similarity: 0.3995)
# 94: switchgrass (Cosine Similarity: 0.3994)
# 95: mesophilic (Cosine Similarity: 0.3991)
# 96: oleds (Cosine Similarity: 0.3990)
# 97: 389 (Cosine Similarity: 0.3984)
# 98: nanofl (Cosine Similarity: 0.3983)
# 99: centrifug (Cosine Similarity: 0.3983)
# 100: culturing (Cosine Similarity: 0.3981)
# 101: hdo (Cosine Similarity: 0.3979)
# 102: λj (Cosine Similarity: 0.3978)
# 103: photoan (Cosine Similarity: 0.3978)
# 104: 454 (Cosine Similarity: 0.3975)
# 105: autophag (Cosine Similarity: 0.3975)
# 106: 037 (Cosine Similarity: 0.3973)
# 107: porphy (Cosine Similarity: 0.3972)
# 108: mitochondri (Cosine Similarity: 0.3972)
# 109: smec (Cosine Similarity: 0.3970)
# 110: thermolysis (Cosine Similarity: 0.3965)
# 111: transplant (Cosine Similarity: 0.3961)
# 112: nanocl (Cosine Similarity: 0.3960)
# 113: trilayer (Cosine Similarity: 0.3958)
# 114: transplantation (Cosine Similarity: 0.3958)
# 115: nanocomp (Cosine Similarity: 0.3957)
# 116: ndr (Cosine Similarity: 0.3953)
# 117: 417 (Cosine Similarity: 0.3953)
# 118: singh (Cosine Similarity: 0.3952)
# 119: mocvd (Cosine Similarity: 0.3949)
# 120: 472 (Cosine Similarity: 0.3947)
# 121: processability (Cosine Similarity: 0.3944)
# 122: degen (Cosine Similarity: 0.3943)
# 123: 456 (Cosine Similarity: 0.3940)
# 124: cs2co3 (Cosine Similarity: 0.3939)
# 125: overestim (Cosine Similarity: 0.3939)
# 126: c27 (Cosine Similarity: 0.3938)
# 127: 034 (Cosine Similarity: 0.3937)
# 128: 029 (Cosine Similarity: 0.3937)
# 129: tct (Cosine Similarity: 0.3936)
# 130: pathogenesis (Cosine Similarity: 0.3935)
# 131: shrna (Cosine Similarity: 0.3933)
# 132: lanthan (Cosine Similarity: 0.3932)
# 133: 386 (Cosine Similarity: 0.3931)
# 134: lignocell (Cosine Similarity: 0.3931)
# 135: photoelectrode (Cosine Similarity: 0.3931)
# 136: photosensitizer (Cosine Similarity: 0.3930)
# 137: senescence (Cosine Similarity: 0.3929)
# 138: aquac (Cosine Similarity: 0.3929)
# 139: al0 (Cosine Similarity: 0.3926)
# 140: phosphorescent (Cosine Similarity: 0.3925)
# 141: impregn (Cosine Similarity: 0.3925)
# 142: photocataly (Cosine Similarity: 0.3924)
# 143: dbr (Cosine Similarity: 0.3921)
# 144: neurodegenerative (Cosine Similarity: 0.3921)
# 145: incineration (Cosine Similarity: 0.3920)
# 146: igzo (Cosine Similarity: 0.3919)
# 147: hscs (Cosine Similarity: 0.3919)
# 148: heterojunctions (Cosine Similarity: 0.3918)
# 149: rehydr (Cosine Similarity: 0.3918)
# 150: hla (Cosine Similarity: 0.3918)
# 151: diffractograms (Cosine Similarity: 0.3917)
# 152: c25 (Cosine Similarity: 0.3917)
# 153: ρl (Cosine Similarity: 0.3916)
# 154: tcl (Cosine Similarity: 0.3914)
# 155: manufact (Cosine Similarity: 0.3914)
# 156: copyr (Cosine Similarity: 0.3909)
# 157: terephthal (Cosine Similarity: 0.3909)
# 158: phytochemical (Cosine Similarity: 0.3907)
# 159: ldhs (Cosine Similarity: 0.3906)
# 160: calif (Cosine Similarity: 0.3904)
# 161: aromatization (Cosine Similarity: 0.3902)
# 162: tlr (Cosine Similarity: 0.3901)
# 163: bronsted (Cosine Similarity: 0.3900)
# 164: overexpressing (Cosine Similarity: 0.3899)
# 165: lineages (Cosine Similarity: 0.3897)
# 166: oxyhydrox (Cosine Similarity: 0.3897)
# 167: frustr (Cosine Similarity: 0.3896)
# 168: p3ht (Cosine Similarity: 0.3894)
# 169: 452 (Cosine Similarity: 0.3894)
# 170: acceler (Cosine Similarity: 0.3892)
# 171: tackle (Cosine Similarity: 0.3892)
# 172: benzod (Cosine Similarity: 0.3891)
# 173: 478 (Cosine Similarity: 0.3890)
# 174: anorth (Cosine Similarity: 0.3890)
# 175: ch3nh3 (Cosine Similarity: 0.3889)
# 176: 383 (Cosine Similarity: 0.3889)
# 177: cambrian (Cosine Similarity: 0.3886)
# 178: lhs (Cosine Similarity: 0.3886)
# 179: wittig (Cosine Similarity: 0.3885)
# 180: 364 (Cosine Similarity: 0.3885)
# 181: qrt (Cosine Similarity: 0.3885)
# 182: infeasible (Cosine Similarity: 0.3882)
# 183: recalcitr (Cosine Similarity: 0.3882)
# 184: anthocyan (Cosine Similarity: 0.3882)
# 185: 376 (Cosine Similarity: 0.3882)
# 186: hypertherm (Cosine Similarity: 0.3881)
# 187: amination (Cosine Similarity: 0.3881)
# 188: 388 (Cosine Similarity: 0.3880)
# 189: tetracycl (Cosine Similarity: 0.3879)
# 190: 508 (Cosine Similarity: 0.3878)
# 191: 483 (Cosine Similarity: 0.3878)
# 192: zl (Cosine Similarity: 0.3877)
# 193: reprogr (Cosine Similarity: 0.3876)
# 194: deoxygenation (Cosine Similarity: 0.3875)
# 195: ophiol (Cosine Similarity: 0.3874)
# 196: 373 (Cosine Similarity: 0.3873)
# 197: si3 (Cosine Similarity: 0.3873)
# 198: biotrans (Cosine Similarity: 0.3871)
# 199: ofets (Cosine Similarity: 0.3871)
# 200: epilayers (Cosine Similarity: 0.3871)
# 201: 299 (Cosine Similarity: 0.3870)
# 202: adsor (Cosine Similarity: 0.3870)
# 203: highl (Cosine Similarity: 0.3870)
# 204: hmm (Cosine Similarity: 0.3868)
# 205: transporter (Cosine Similarity: 0.3868)
# 206: moho (Cosine Similarity: 0.3867)
# 207: chlorella (Cosine Similarity: 0.3867)
# 208: swir (Cosine Similarity: 0.3867)
# 209: cupc (Cosine Similarity: 0.3865)
# 210: 036 (Cosine Similarity: 0.3864)
# 211: corrobor (Cosine Similarity: 0.3863)
# 212: digesters (Cosine Similarity: 0.3862)
# 213: lique (Cosine Similarity: 0.3861)
# 214: nitridation (Cosine Similarity: 0.3860)
# 215: lipof (Cosine Similarity: 0.3860)
# 216: alq3 (Cosine Similarity: 0.3859)
# 217: oscs (Cosine Similarity: 0.3858)
# 218: hydroxyphenyl (Cosine Similarity: 0.3858)
# 219: glcn (Cosine Similarity: 0.3856)
# 220: 474 (Cosine Similarity: 0.3856)
# 221: ensemb (Cosine Similarity: 0.3855)
# 222: promot (Cosine Similarity: 0.3855)
# 223: s3a (Cosine Similarity: 0.3854)
# 224: expl (Cosine Similarity: 0.3853)
# 225: 5t (Cosine Similarity: 0.3853)
# 226: upwelling (Cosine Similarity: 0.3853)
# 227: mhc (Cosine Similarity: 0.3853)
# 228: chemotherapeutic (Cosine Similarity: 0.3853)
# 229: transpar (Cosine Similarity: 0.3852)
# 230: amphiphiles (Cosine Similarity: 0.3852)
# 231: marcus (Cosine Similarity: 0.3850)
# 232: mbt (Cosine Similarity: 0.3849)
# 233: exosomes (Cosine Similarity: 0.3849)
# 234: nanocarriers (Cosine Similarity: 0.3846)
# 235: transesterification (Cosine Similarity: 0.3845)
# 236: 433 (Cosine Similarity: 0.3845)
# 237: hydroge (Cosine Similarity: 0.3845)
# 238: toxicological (Cosine Similarity: 0.3845)
# 239: thermalization (Cosine Similarity: 0.3844)
# 240: circumvent (Cosine Similarity: 0.3844)
# 241: liposomal (Cosine Similarity: 0.3844)
# 242: hydrous (Cosine Similarity: 0.3844)
# 243: ferul (Cosine Similarity: 0.3844)
# 244: diaster (Cosine Similarity: 0.3842)
# 245: gasifier (Cosine Similarity: 0.3842)
# 246: montm (Cosine Similarity: 0.3840)
# 247: protonic (Cosine Similarity: 0.3839)
# 248: 370 (Cosine Similarity: 0.3839)
# 249: 448 (Cosine Similarity: 0.3838)
# 250: ferrom (Cosine Similarity: 0.3838)
# 251: 044 (Cosine Similarity: 0.3837)
# 252: nanotub (Cosine Similarity: 0.3834)
# 253: brominated (Cosine Similarity: 0.3833)
# 254: combust (Cosine Similarity: 0.3832)
# 255: coroll (Cosine Similarity: 0.3831)
# 256: introduc (Cosine Similarity: 0.3831)
# 257: mgal (Cosine Similarity: 0.3831)
# 258: hydroxylated (Cosine Similarity: 0.3830)
# 259: clayey (Cosine Similarity: 0.3830)
# 260: hemicell (Cosine Similarity: 0.3830)
# 261: pervaporation (Cosine Similarity: 0.3830)
# 262: thermograv (Cosine Similarity: 0.3829)
# 263: toluenesulf (Cosine Similarity: 0.3829)
# 264: lysosomes (Cosine Similarity: 0.3829)
# 265: efflu (Cosine Similarity: 0.3828)
# 266: 9h2o (Cosine Similarity: 0.3828)
# 267: beij (Cosine Similarity: 0.3828)
# 268: workup (Cosine Similarity: 0.3828)
# 269: lignocellulosic (Cosine Similarity: 0.3828)
# 270: nanopartic (Cosine Similarity: 0.3827)
# 271: pretreatments (Cosine Similarity: 0.3827)
# 272: monochrom (Cosine Similarity: 0.3827)
# 273: kumar (Cosine Similarity: 0.3825)
# 274: 337 (Cosine Similarity: 0.3825)
# 275: phili (Cosine Similarity: 0.3824)
# 276: cbp (Cosine Similarity: 0.3824)
# 277: mitig (Cosine Similarity: 0.3823)
# 278: retriev (Cosine Similarity: 0.3823)
# 279: lipop (Cosine Similarity: 0.3822)
# 280: inflamm (Cosine Similarity: 0.3822)
# 281: combustor (Cosine Similarity: 0.3822)
# 282: 484 (Cosine Similarity: 0.3821)
# 283: c26 (Cosine Similarity: 0.3821)
# 284: hydroxyp (Cosine Similarity: 0.3821)
# 285: hydrochlor (Cosine Similarity: 0.3821)
# 286: scalability (Cosine Similarity: 0.3821)
# 287: qws (Cosine Similarity: 0.3820)
# 288: tibet (Cosine Similarity: 0.3820)
# 289: perovskites (Cosine Similarity: 0.3819)
# 290: tributaries (Cosine Similarity: 0.3819)
# 291: amphiph (Cosine Similarity: 0.3819)
# 292: coprecip (Cosine Similarity: 0.3819)
# 293: cultivars (Cosine Similarity: 0.3819)
# 294: expander (Cosine Similarity: 0.3818)
# 295: bnt (Cosine Similarity: 0.3818)
# 296: ultraf (Cosine Similarity: 0.3817)
# 297: calcination (Cosine Similarity: 0.3817)
# 298: 426 (Cosine Similarity: 0.3816)
# 299: 038 (Cosine Similarity: 0.3816)
# 300: photogen (Cosine Similarity: 0.3815)
# 301: tbp (Cosine Similarity: 0.3815)
# 302: photocathode (Cosine Similarity: 0.3814)
# 303: 382 (Cosine Similarity: 0.3813)
# 304: alkyn (Cosine Similarity: 0.3813)
# 305: paly (Cosine Similarity: 0.3812)
# 306: 5l (Cosine Similarity: 0.3812)
# 307: hydroly (Cosine Similarity: 0.3812)
# 308: 367 (Cosine Similarity: 0.3811)
# 309: zrp (Cosine Similarity: 0.3810)
# 310: bromination (Cosine Similarity: 0.3810)
# 311: eutrophication (Cosine Similarity: 0.3808)
# 312: herbic (Cosine Similarity: 0.3808)
# 313: cyclisation (Cosine Similarity: 0.3808)
# 314: headgroup (Cosine Similarity: 0.3808)
# 315: tph (Cosine Similarity: 0.3808)
# 316: transporting (Cosine Similarity: 0.3806)
# 317: describ (Cosine Similarity: 0.3805)
# 318: oxic (Cosine Similarity: 0.3805)
# 319: h2l (Cosine Similarity: 0.3804)
# 320: tsr (Cosine Similarity: 0.3804)
# 321: obesity (Cosine Similarity: 0.3804)
# 322: condens (Cosine Similarity: 0.3804)
# 323: heterotrophic (Cosine Similarity: 0.3803)
# 324: 675 (Cosine Similarity: 0.3803)
# 325: precip (Cosine Similarity: 0.3803)
# 326: irresp (Cosine Similarity: 0.3802)
# 327: pvk (Cosine Similarity: 0.3802)
# 328: 328 (Cosine Similarity: 0.3799)
# 329: peristal (Cosine Similarity: 0.3799)
# 330: 6890 (Cosine Similarity: 0.3799)
# 331: 4200 (Cosine Similarity: 0.3797)
# 332: ultramafic (Cosine Similarity: 0.3797)
# 333: hydrolyze (Cosine Similarity: 0.3796)
# 334: hydrox (Cosine Similarity: 0.3795)
# 335: eutroph (Cosine Similarity: 0.3794)
# 336: pscs (Cosine Similarity: 0.3794)
# 337: exfol (Cosine Similarity: 0.3793)
# 338: elucidating (Cosine Similarity: 0.3793)
# 339: gasification (Cosine Similarity: 0.3793)
# 340: volati (Cosine Similarity: 0.3792)
# 341: stagn (Cosine Similarity: 0.3792)
# 342: mercapt (Cosine Similarity: 0.3792)
# 343: unphysical (Cosine Similarity: 0.3791)
# 344: plagi (Cosine Similarity: 0.3791)
# 345: 2920 (Cosine Similarity: 0.3791)
# 346: 487 (Cosine Similarity: 0.3791)
# 347: elabor (Cosine Similarity: 0.3791)
# 348: pyroly (Cosine Similarity: 0.3791)
# 349: baffles (Cosine Similarity: 0.3790)
# 350: explor (Cosine Similarity: 0.3789)
# 351: elig (Cosine Similarity: 0.3788)
# 352: nanogels (Cosine Similarity: 0.3788)
# 353: xrpd (Cosine Similarity: 0.3787)
# 354: 493 (Cosine Similarity: 0.3787)
# 355: 449 (Cosine Similarity: 0.3786)
# 356: ignited (Cosine Similarity: 0.3786)
# 357: nontr (Cosine Similarity: 0.3786)
# 358: 065 (Cosine Similarity: 0.3786)
# 359: thermophilic (Cosine Similarity: 0.3785)
# 360: wavegu (Cosine Similarity: 0.3785)
# 361: stere (Cosine Similarity: 0.3784)
# 362: carbohydr (Cosine Similarity: 0.3784)
# 363: hydrogenolysis (Cosine Similarity: 0.3784)
# 364: 823 (Cosine Similarity: 0.3782)
# 365: astrocytes (Cosine Similarity: 0.3782)
# 366: opv (Cosine Similarity: 0.3781)
# 367: conclu (Cosine Similarity: 0.3781)
# 368: photooxidation (Cosine Similarity: 0.3780)
# 369: coumar (Cosine Similarity: 0.3780)
# 370: lithologies (Cosine Similarity: 0.3780)
# 371: diamin (Cosine Similarity: 0.3780)
# 372: dinit (Cosine Similarity: 0.3779)
# 373: vascul (Cosine Similarity: 0.3779)
# 374: 369 (Cosine Similarity: 0.3778)
# 375: optoelectronics (Cosine Similarity: 0.3778)
# 376: supernatants (Cosine Similarity: 0.3777)
# 377: biotransformation (Cosine Similarity: 0.3776)
# 378: manufactur (Cosine Similarity: 0.3776)
# 379: nanohybrids (Cosine Similarity: 0.3775)
# 380: deoxygen (Cosine Similarity: 0.3774)
# 381: encryp (Cosine Similarity: 0.3774)
# 382: wwtp (Cosine Similarity: 0.3773)
# 383: entrap (Cosine Similarity: 0.3772)
# 384: mediter (Cosine Similarity: 0.3772)
# 385: alkoxy (Cosine Similarity: 0.3772)
# 386: sclc (Cosine Similarity: 0.3772)
# 387: nanohybrid (Cosine Similarity: 0.3772)
# 388: cataly (Cosine Similarity: 0.3771)
# 389: iup (Cosine Similarity: 0.3769)
# 390: 368 (Cosine Similarity: 0.3769)
# 391: immisc (Cosine Similarity: 0.3769)
# 392: photocurrents (Cosine Similarity: 0.3769)
# 393: hept (Cosine Similarity: 0.3767)
# 394: constitu (Cosine Similarity: 0.3766)
# 395: autophagy (Cosine Similarity: 0.3766)
# 396: 434 (Cosine Similarity: 0.3766)
# 397: encodes (Cosine Similarity: 0.3764)
# 398: hepar (Cosine Similarity: 0.3763)
# 399: unfavour (Cosine Similarity: 0.3763)
# 400: organoc (Cosine Similarity: 0.3763)
# 401: sorbents (Cosine Similarity: 0.3762)
# 402: raph (Cosine Similarity: 0.3762)
# 403: nucleoph (Cosine Similarity: 0.3762)
# 404: 5406 (Cosine Similarity: 0.3761)
# 405: 815 (Cosine Similarity: 0.3761)
# 406: 5o2 (Cosine Similarity: 0.3760)
# 407: slur (Cosine Similarity: 0.3759)
# 408: 18a (Cosine Similarity: 0.3758)
# 409: hul (Cosine Similarity: 0.3758)
# 410: tryp (Cosine Similarity: 0.3758)
# 411: 366 (Cosine Similarity: 0.3758)
# 412: lear (Cosine Similarity: 0.3757)
# 413: pestic (Cosine Similarity: 0.3757)
# 414: regenerator (Cosine Similarity: 0.3757)
# 415: sapon (Cosine Similarity: 0.3756)
# 416: photoexc (Cosine Similarity: 0.3756)
# 417: colorectal (Cosine Similarity: 0.3755)
# 418: kaz (Cosine Similarity: 0.3754)
# 419: substantiated (Cosine Similarity: 0.3754)
# 420: ﬂ (Cosine Similarity: 0.3754)
# 421: nitroc (Cosine Similarity: 0.3754)
# 422: theore (Cosine Similarity: 0.3754)
# 423: delaminated (Cosine Similarity: 0.3754)
# 424: dissimil (Cosine Similarity: 0.3754)
# 425: 268 (Cosine Similarity: 0.3753)
# 426: nitrox (Cosine Similarity: 0.3752)
# 427: photodetectors (Cosine Similarity: 0.3752)
# 428: detoxification (Cosine Similarity: 0.3751)
# 429: differenti (Cosine Similarity: 0.3750)
# 430: 032 (Cosine Similarity: 0.3750)
# 431: solubilities (Cosine Similarity: 0.3749)
# 432: superconduc (Cosine Similarity: 0.3748)
# 433: aglyc (Cosine Similarity: 0.3747)
# 434: stic (Cosine Similarity: 0.3747)
# 435: numerator (Cosine Similarity: 0.3747)
# 436: 5418 (Cosine Similarity: 0.3747)
# 437: generat (Cosine Similarity: 0.3747)
# 438: hmp (Cosine Similarity: 0.3746)
# 439: in0 (Cosine Similarity: 0.3746)
# 440: hek293 (Cosine Similarity: 0.3745)
# 441: alkylation (Cosine Similarity: 0.3745)
# 442: discrep (Cosine Similarity: 0.3745)
# 443: roofs (Cosine Similarity: 0.3744)
# 444: inconsist (Cosine Similarity: 0.3744)
# 445: upregulated (Cosine Similarity: 0.3744)
# 446: methylcycl (Cosine Similarity: 0.3743)
# 447: aggrav (Cosine Similarity: 0.3742)
# 448: 467 (Cosine Similarity: 0.3741)
# 449: imports (Cosine Similarity: 0.3741)
# 450: dimin (Cosine Similarity: 0.3741)
# 451: 459 (Cosine Similarity: 0.3740)
# 452: swcn (Cosine Similarity: 0.3740)
# 453: serpentin (Cosine Similarity: 0.3739)
# 454: overlain (Cosine Similarity: 0.3738)
# 455: liang (Cosine Similarity: 0.3738)
# 456: 042 (Cosine Similarity: 0.3737)
# 457: vul (Cosine Similarity: 0.3737)
# 458: thermionic (Cosine Similarity: 0.3736)
# 459: kore (Cosine Similarity: 0.3736)
# 460: aquifers (Cosine Similarity: 0.3736)
# 461: metallurg (Cosine Similarity: 0.3736)
# 462: hect (Cosine Similarity: 0.3736)
# 463: hydroformylation (Cosine Similarity: 0.3735)
# 464: edible (Cosine Similarity: 0.3735)
# 465: clade (Cosine Similarity: 0.3735)
# 466: lialh4 (Cosine Similarity: 0.3734)
# 467: 860 (Cosine Similarity: 0.3734)
# 468: 030 (Cosine Similarity: 0.3734)
# 469: upgrading (Cosine Similarity: 0.3733)
# 470: varie (Cosine Similarity: 0.3733)
# 471: lubricants (Cosine Similarity: 0.3733)
# 472: buoh (Cosine Similarity: 0.3733)
# 473: zheng (Cosine Similarity: 0.3732)
# 474: perovsk (Cosine Similarity: 0.3732)
# 475: transplanted (Cosine Similarity: 0.3732)
# 476: upregulation (Cosine Similarity: 0.3732)
# 477: ozonation (Cosine Similarity: 0.3732)
# 478: precurs (Cosine Similarity: 0.3731)
# 479: 518 (Cosine Similarity: 0.3730)
# 480: inund (Cosine Similarity: 0.3729)
# 481: rtils (Cosine Similarity: 0.3728)
# 482: 396 (Cosine Similarity: 0.3728)
# 483: uvb (Cosine Similarity: 0.3727)
# 484: plank (Cosine Similarity: 0.3727)
# 485: ti0 (Cosine Similarity: 0.3727)
# 486: pyridin (Cosine Similarity: 0.3727)
# 487: gastrointestinal (Cosine Similarity: 0.3726)
# 488: 060 (Cosine Similarity: 0.3726)
# 489: james (Cosine Similarity: 0.3726)
# 490: biofil (Cosine Similarity: 0.3726)
# 491: uhplc (Cosine Similarity: 0.3726)
# 492: refinery (Cosine Similarity: 0.3725)
# 493: haadf (Cosine Similarity: 0.3723)
# 494: heteroj (Cosine Similarity: 0.3721)
# 495: himal (Cosine Similarity: 0.3721)
# 496: 357 (Cosine Similarity: 0.3721)
# 497: c19 (Cosine Similarity: 0.3720)
# 498: upreg (Cosine Similarity: 0.3720)
# 499: thienyl (Cosine Similarity: 0.3720)
# 500: baking (Cosine Similarity: 0.3720)
# 501: 930 (Cosine Similarity: 0.3720)
# 502: zha (Cosine Similarity: 0.3720)
# 503: 033 (Cosine Similarity: 0.3719)
# 504: arabin (Cosine Similarity: 0.3719)
# 505: 354 (Cosine Similarity: 0.3719)
# 506: stover (Cosine Similarity: 0.3719)
# 507: sonog (Cosine Similarity: 0.3719)
# 508: 3l (Cosine Similarity: 0.3718)
# 509: ethylhexyl (Cosine Similarity: 0.3718)
# 510: epil (Cosine Similarity: 0.3718)
# 511: thermograms (Cosine Similarity: 0.3717)
# 512: straightforwardly (Cosine Similarity: 0.3717)
# 513: mesoph (Cosine Similarity: 0.3717)
# 514: formulating (Cosine Similarity: 0.3717)
# 515: mord (Cosine Similarity: 0.3716)
# 516: 408 (Cosine Similarity: 0.3716)
# 517: 435 (Cosine Similarity: 0.3716)
# 518: 349 (Cosine Similarity: 0.3715)
# 519: electroluminescence (Cosine Similarity: 0.3714)
# 520: 723 (Cosine Similarity: 0.3714)
# 521: ucnps (Cosine Similarity: 0.3714)
# 522: ℝ (Cosine Similarity: 0.3714)
# 523: urbanization (Cosine Similarity: 0.3713)
# 524: fertilizers (Cosine Similarity: 0.3713)
# 525: 348 (Cosine Similarity: 0.3712)
# 526: 458 (Cosine Similarity: 0.3712)
# 527: 028 (Cosine Similarity: 0.3712)
# 528: hdac (Cosine Similarity: 0.3711)
# 529: composting (Cosine Similarity: 0.3711)
# 530: osteogenic (Cosine Similarity: 0.3711)
# 531: epitax (Cosine Similarity: 0.3710)
# 532: drawbacks (Cosine Similarity: 0.3710)
# 533: lew (Cosine Similarity: 0.3710)
# 534: hdl (Cosine Similarity: 0.3709)
# 535: hbn (Cosine Similarity: 0.3709)
# 536: heaters (Cosine Similarity: 0.3708)
# 537: lini0 (Cosine Similarity: 0.3708)
# 538: guid (Cosine Similarity: 0.3708)
# 539: mniii (Cosine Similarity: 0.3708)
# 540: θn (Cosine Similarity: 0.3707)
# 541: electropor (Cosine Similarity: 0.3707)
# 542: mppt (Cosine Similarity: 0.3707)
# 543: 395 (Cosine Similarity: 0.3707)
# 544: μh (Cosine Similarity: 0.3706)
# 545: incubations (Cosine Similarity: 0.3706)
# 546: kerogen (Cosine Similarity: 0.3706)
# 547: spectrophot (Cosine Similarity: 0.3705)
# 548: detox (Cosine Similarity: 0.3705)
# 549: 466 (Cosine Similarity: 0.3705)
# 550: 4t (Cosine Similarity: 0.3705)
# 551: htf (Cosine Similarity: 0.3704)
# 552: 387 (Cosine Similarity: 0.3704)
# 553: angiogenic (Cosine Similarity: 0.3704)
# 554: nicotin (Cosine Similarity: 0.3704)
# 555: lcm (Cosine Similarity: 0.3704)
# 556: elucidate (Cosine Similarity: 0.3704)
# 557: thiophen (Cosine Similarity: 0.3704)
# 558: extractant (Cosine Similarity: 0.3703)
# 559: ⅲ (Cosine Similarity: 0.3703)
# 560: adipocytes (Cosine Similarity: 0.3702)
# 561: vermic (Cosine Similarity: 0.3701)
# 562: hso4 (Cosine Similarity: 0.3701)
# 563: hematopoietic (Cosine Similarity: 0.3700)
# 564: 2018 (Cosine Similarity: 0.3700)
# 565: pmf (Cosine Similarity: 0.3700)
# 566: lmct (Cosine Similarity: 0.3699)
# 567: photodynamic (Cosine Similarity: 0.3698)
# 568: otus (Cosine Similarity: 0.3698)
# 569: anthra (Cosine Similarity: 0.3697)
# 570: inks (Cosine Similarity: 0.3697)
# 571: kaol (Cosine Similarity: 0.3697)
# 572: biodegrad (Cosine Similarity: 0.3696)
# 573: montmorill (Cosine Similarity: 0.3696)
# 574: 045 (Cosine Similarity: 0.3696)
# 575: supercapac (Cosine Similarity: 0.3696)
# 576: dρ (Cosine Similarity: 0.3695)
# 577: molybd (Cosine Similarity: 0.3695)
# 578: glycolysis (Cosine Similarity: 0.3695)
# 579: 394 (Cosine Similarity: 0.3694)
# 580: 425 (Cosine Similarity: 0.3694)
# 581: nanoribb (Cosine Similarity: 0.3694)
# 582: landsc (Cosine Similarity: 0.3693)
# 583: 355 (Cosine Similarity: 0.3692)
# 584: autocl (Cosine Similarity: 0.3692)
# 585: glycoproteins (Cosine Similarity: 0.3691)
# 586: ρn (Cosine Similarity: 0.3691)
# 587: mtor (Cosine Similarity: 0.3690)
# 588: triti (Cosine Similarity: 0.3690)
# 589: isothi (Cosine Similarity: 0.3689)
# 590: endosomes (Cosine Similarity: 0.3688)
# 591: gyp (Cosine Similarity: 0.3688)
# 592: unreason (Cosine Similarity: 0.3688)
# 593: biotechn (Cosine Similarity: 0.3687)
# 594: 915 (Cosine Similarity: 0.3687)
# 595: 3300 (Cosine Similarity: 0.3686)
# 596: depos (Cosine Similarity: 0.3686)
# 597: dibrom (Cosine Similarity: 0.3686)
# 598: spik (Cosine Similarity: 0.3686)
# 599: lhv (Cosine Similarity: 0.3686)
# 600: villages (Cosine Similarity: 0.3686)
# 601: chann (Cosine Similarity: 0.3686)
# 602: 447 (Cosine Similarity: 0.3685)
# 603: enti (Cosine Similarity: 0.3684)
# 604: mmt (Cosine Similarity: 0.3684)
# 605: lenn (Cosine Similarity: 0.3683)
# 606: 027 (Cosine Similarity: 0.3683)
# 607: pc61 (Cosine Similarity: 0.3682)
# 608: cu2s (Cosine Similarity: 0.3682)
# 609: altitudes (Cosine Similarity: 0.3682)
# 610: jx (Cosine Similarity: 0.3682)
# 611: electrol (Cosine Similarity: 0.3682)
# 612: rifting (Cosine Similarity: 0.3682)
# 613: photoactive (Cosine Similarity: 0.3682)
# 614: melanin (Cosine Similarity: 0.3681)
# 615: 003 (Cosine Similarity: 0.3681)
# 616: cathodes (Cosine Similarity: 0.3681)
# 617: nitriding (Cosine Similarity: 0.3681)
# 618: hepat (Cosine Similarity: 0.3680)
# 619: qing (Cosine Similarity: 0.3680)
# 620: riverine (Cosine Similarity: 0.3680)
# 621: perh (Cosine Similarity: 0.3680)
# 622: photocatalysis (Cosine Similarity: 0.3680)
# 623: dehydrox (Cosine Similarity: 0.3680)
# 624: pdt (Cosine Similarity: 0.3680)
# 625: transcriptome (Cosine Similarity: 0.3679)
# 626: monohydr (Cosine Similarity: 0.3679)
# 627: hbt (Cosine Similarity: 0.3679)
# 628: devolatil (Cosine Similarity: 0.3678)
# 629: 515 (Cosine Similarity: 0.3678)
# 630: zeol (Cosine Similarity: 0.3678)
# 631: whatman (Cosine Similarity: 0.3677)
# 632: mlp (Cosine Similarity: 0.3677)
# 633: tbhp (Cosine Similarity: 0.3677)
# 634: mth (Cosine Similarity: 0.3677)
# 635: encr (Cosine Similarity: 0.3676)
# 636: phenylprop (Cosine Similarity: 0.3675)
# 637: hierarchically (Cosine Similarity: 0.3675)
# 638: thailand (Cosine Similarity: 0.3674)
# 639: thermopower (Cosine Similarity: 0.3673)
# 640: artif (Cosine Similarity: 0.3673)
# 641: xenogr (Cosine Similarity: 0.3672)
# 642: citing (Cosine Similarity: 0.3671)
# 643: 438 (Cosine Similarity: 0.3671)
# 644: subduc (Cosine Similarity: 0.3670)
# 645: olig (Cosine Similarity: 0.3670)
# 646: confounding (Cosine Similarity: 0.3670)
# 647: pyrid (Cosine Similarity: 0.3670)
# 648: ambipolar (Cosine Similarity: 0.3670)
# 649: ilm (Cosine Similarity: 0.3669)
# 650: tocopher (Cosine Similarity: 0.3669)
# 651: sugarcane (Cosine Similarity: 0.3669)
# 652: polyoxometal (Cosine Similarity: 0.3669)
# 653: 775 (Cosine Similarity: 0.3669)
# 654: reformer (Cosine Similarity: 0.3668)
# 655: upcon (Cosine Similarity: 0.3668)
# 656: electrodepos (Cosine Similarity: 0.3667)
# 657: undoub (Cosine Similarity: 0.3666)
# 658: c57 (Cosine Similarity: 0.3665)
# 659: corrug (Cosine Similarity: 0.3665)
# 660: hypoxic (Cosine Similarity: 0.3664)
# 661: fundament (Cosine Similarity: 0.3664)
# 662: semiconduc (Cosine Similarity: 0.3664)
# 663: ln3 (Cosine Similarity: 0.3664)
# 664: reflectors (Cosine Similarity: 0.3664)
# 665: profitability (Cosine Similarity: 0.3664)
# 666: disciplines (Cosine Similarity: 0.3663)
# 667: tect (Cosine Similarity: 0.3663)
# 668: hologr (Cosine Similarity: 0.3663)
# 669: p4vp (Cosine Similarity: 0.3663)
# 670: nanoflow (Cosine Similarity: 0.3663)
# 671: allevi (Cosine Similarity: 0.3662)
# 672: 446 (Cosine Similarity: 0.3662)
# 673: glucosidase (Cosine Similarity: 0.3662)
# 674: guai (Cosine Similarity: 0.3661)
# 675: leukocytes (Cosine Similarity: 0.3661)
# 676: chh (Cosine Similarity: 0.3661)
# 677: endosomal (Cosine Similarity: 0.3661)
# 678: transcriptase (Cosine Similarity: 0.3661)
# 679: 442 (Cosine Similarity: 0.3660)
# 680: herbs (Cosine Similarity: 0.3660)
# 681: underst (Cosine Similarity: 0.3659)
# 682: ooh (Cosine Similarity: 0.3658)
# 683: tbt (Cosine Similarity: 0.3658)
# 684: gord (Cosine Similarity: 0.3658)
# 685: uncontroll (Cosine Similarity: 0.3657)
# 686: wearable (Cosine Similarity: 0.3657)
# 687: deintercal (Cosine Similarity: 0.3656)
# 688: herbicides (Cosine Similarity: 0.3656)
# 689: carls (Cosine Similarity: 0.3656)
# 690: 397 (Cosine Similarity: 0.3656)
# 691: θk (Cosine Similarity: 0.3655)
# 692: biopro (Cosine Similarity: 0.3655)
# 693: digestive (Cosine Similarity: 0.3654)
# 694: skelet (Cosine Similarity: 0.3654)
# 695: provinces (Cosine Similarity: 0.3654)
# 696: legs (Cosine Similarity: 0.3654)
# 697: hpo4 (Cosine Similarity: 0.3653)
# 698: strati (Cosine Similarity: 0.3653)
# 699: pi3k (Cosine Similarity: 0.3653)
# 700: downloaded (Cosine Similarity: 0.3653)
# 701: hzsm (Cosine Similarity: 0.3652)
# 702: pakistan (Cosine Similarity: 0.3651)
# 703: lagr (Cosine Similarity: 0.3651)
# 704: pml (Cosine Similarity: 0.3650)
# 705: ldos (Cosine Similarity: 0.3650)
# 706: waf (Cosine Similarity: 0.3650)
# 707: lgm (Cosine Similarity: 0.3649)
# 708: 2λ (Cosine Similarity: 0.3649)
# 709: trinuclear (Cosine Similarity: 0.3649)
# 710: zet (Cosine Similarity: 0.3649)
# 711: cigaret (Cosine Similarity: 0.3649)
# 712: encaps (Cosine Similarity: 0.3649)
# 713: 2ρ (Cosine Similarity: 0.3648)
# 714: 398 (Cosine Similarity: 0.3648)
# 715: boehmite (Cosine Similarity: 0.3648)
# 716: hyperthermia (Cosine Similarity: 0.3648)
# 717: volcan (Cosine Similarity: 0.3647)
# 718: scopus (Cosine Similarity: 0.3647)
# 719: inkjet (Cosine Similarity: 0.3647)
# 720: pathophy (Cosine Similarity: 0.3647)
# 721: chemometric (Cosine Similarity: 0.3647)
# 722: polycondensation (Cosine Similarity: 0.3647)
# 723: tpu (Cosine Similarity: 0.3646)
# 724: mtx (Cosine Similarity: 0.3646)
# 725: solub (Cosine Similarity: 0.3646)
# 726: 334 (Cosine Similarity: 0.3645)
# 727: apci (Cosine Similarity: 0.3645)
# 728: haze (Cosine Similarity: 0.3644)
# 729: segreg (Cosine Similarity: 0.3644)
# 730: histopath (Cosine Similarity: 0.3643)
# 731: reduc (Cosine Similarity: 0.3643)
# 732: polyelectrolytes (Cosine Similarity: 0.3643)
# 733: neglig (Cosine Similarity: 0.3643)
# 734: 269 (Cosine Similarity: 0.3643)
# 735: evapor (Cosine Similarity: 0.3643)
# 736: nife2o4 (Cosine Similarity: 0.3642)
# 737: interes (Cosine Similarity: 0.3642)
# 738: estim (Cosine Similarity: 0.3642)
# 739: c4mim (Cosine Similarity: 0.3642)
# 740: diffractogram (Cosine Similarity: 0.3641)
# 741: supernat (Cosine Similarity: 0.3641)
# 742: solvers (Cosine Similarity: 0.3640)
# 743: isent (Cosine Similarity: 0.3639)
# 744: waxd (Cosine Similarity: 0.3639)
# 745: alkenyl (Cosine Similarity: 0.3639)
# 746: hosted (Cosine Similarity: 0.3639)
# 747: 1240 (Cosine Similarity: 0.3638)
# 748: immunop (Cosine Similarity: 0.3638)
# 749: ampho (Cosine Similarity: 0.3638)
# 750: metamorphism (Cosine Similarity: 0.3638)
# 751: photosynthesis (Cosine Similarity: 0.3637)
# 752: 715 (Cosine Similarity: 0.3637)
# 753: hydroxo (Cosine Similarity: 0.3637)
# 754: 𝐫 (Cosine Similarity: 0.3636)
# 755: chloromethyl (Cosine Similarity: 0.3636)
# 756: overlo (Cosine Similarity: 0.3636)
# 757: advective (Cosine Similarity: 0.3636)
# 758: sulfonation (Cosine Similarity: 0.3635)
# 759: carbam (Cosine Similarity: 0.3635)
# 760: protic (Cosine Similarity: 0.3635)
# 761: overburden (Cosine Similarity: 0.3634)
# 762: emplaced (Cosine Similarity: 0.3634)
# 763: 3500 (Cosine Similarity: 0.3633)
# 764: 008 (Cosine Similarity: 0.3633)
# 765: larg (Cosine Similarity: 0.3633)
# 766: 353 (Cosine Similarity: 0.3633)
# 767: orth (Cosine Similarity: 0.3632)
# 768: photodegrad (Cosine Similarity: 0.3632)
# 769: dolom (Cosine Similarity: 0.3632)
# 770: implementations (Cosine Similarity: 0.3632)
# 771: eqe (Cosine Similarity: 0.3632)
# 772: carcinogenic (Cosine Similarity: 0.3632)
# 773: holograph (Cosine Similarity: 0.3632)
# 774: rationally (Cosine Similarity: 0.3632)
# 775: distill (Cosine Similarity: 0.3632)
# 776: submic (Cosine Similarity: 0.3631)
# 777: immunohistochemistry (Cosine Similarity: 0.3631)
# 778: 16h (Cosine Similarity: 0.3631)
# 779: jap (Cosine Similarity: 0.3631)
# 780: unkn (Cosine Similarity: 0.3630)
# 781: trich (Cosine Similarity: 0.3630)
# 782: negl (Cosine Similarity: 0.3630)
# 783: enzym (Cosine Similarity: 0.3629)
# 784: pyrrolic (Cosine Similarity: 0.3629)
# 785: curc (Cosine Similarity: 0.3629)
# 786: electroneg (Cosine Similarity: 0.3629)
# 787: palyn (Cosine Similarity: 0.3629)
# 788: hydrom (Cosine Similarity: 0.3629)
# 789: preclinical (Cosine Similarity: 0.3629)
# 790: explanatory (Cosine Similarity: 0.3629)
# 791: stereoisomers (Cosine Similarity: 0.3629)
# 792: 009 (Cosine Similarity: 0.3628)
# 793: biomed (Cosine Similarity: 0.3628)
# 794: richard (Cosine Similarity: 0.3628)
# 795: cropl (Cosine Similarity: 0.3628)
# 796: reviewing (Cosine Similarity: 0.3628)
# 797: therapeutics (Cosine Similarity: 0.3627)
# 798: vesic (Cosine Similarity: 0.3627)
# 799: tosyl (Cosine Similarity: 0.3626)
# 800: derivati (Cosine Similarity: 0.3626)
# 801: lipases (Cosine Similarity: 0.3626)
# 802: backbones (Cosine Similarity: 0.3625)
# 803: pharm (Cosine Similarity: 0.3625)
# 804: 339 (Cosine Similarity: 0.3625)
# 805: microgl (Cosine Similarity: 0.3624)
# 806: casc (Cosine Similarity: 0.3624)
# 807: hph (Cosine Similarity: 0.3623)
# 808: nanjing (Cosine Similarity: 0.3623)
# 809: pyruv (Cosine Similarity: 0.3623)
# 810: catalyzing (Cosine Similarity: 0.3623)
# 811: 476 (Cosine Similarity: 0.3623)
# 812: 297 (Cosine Similarity: 0.3623)
# 813: panalytical (Cosine Similarity: 0.3623)
# 814: pyroph (Cosine Similarity: 0.3622)
# 815: methanogenesis (Cosine Similarity: 0.3622)
# 816: jurisdiction (Cosine Similarity: 0.3622)
# 817: stromal (Cosine Similarity: 0.3622)
# 818: thermocline (Cosine Similarity: 0.3622)
# 819: immobilizing (Cosine Similarity: 0.3621)
# 820: 455 (Cosine Similarity: 0.3621)
# 821: λt (Cosine Similarity: 0.3621)
# 822: lacustrine (Cosine Similarity: 0.3621)
# 823: overexpressed (Cosine Similarity: 0.3621)
# 824: sulfon (Cosine Similarity: 0.3621)
# 825: lubricating (Cosine Similarity: 0.3621)
# 826: aladdin (Cosine Similarity: 0.3621)
# 827: mtdna (Cosine Similarity: 0.3621)
# 828: explan (Cosine Similarity: 0.3620)
# 829: rsh (Cosine Similarity: 0.3620)
# 830: excav (Cosine Similarity: 0.3619)
# 831: mlr (Cosine Similarity: 0.3619)
# 832: laun (Cosine Similarity: 0.3619)
# 833: dechlor (Cosine Similarity: 0.3619)
# 834: 923 (Cosine Similarity: 0.3618)
# 835: fruct (Cosine Similarity: 0.3618)
# 836: dispersibility (Cosine Similarity: 0.3618)
# 837: tetradec (Cosine Similarity: 0.3618)
# 838: 437 (Cosine Similarity: 0.3618)
# 839: moo3 (Cosine Similarity: 0.3618)
# 840: carrageen (Cosine Similarity: 0.3618)
# 841: thermogravimetry (Cosine Similarity: 0.3617)
# 842: 695 (Cosine Similarity: 0.3617)
# 843: felsic (Cosine Similarity: 0.3617)
# 844: 5o4 (Cosine Similarity: 0.3617)
# 845: 324 (Cosine Similarity: 0.3617)
# 846: 19a (Cosine Similarity: 0.3617)
# 847: kolmog (Cosine Similarity: 0.3617)
# 848: buyer (Cosine Similarity: 0.3617)
# 849: lmp (Cosine Similarity: 0.3616)
# 850: biole (Cosine Similarity: 0.3616)
# 851: glycosylation (Cosine Similarity: 0.3616)
# 852: olef (Cosine Similarity: 0.3616)
# 853: degrad (Cosine Similarity: 0.3616)
# 854: reperfusion (Cosine Similarity: 0.3615)
# 855: febr (Cosine Similarity: 0.3615)
# 856: cct (Cosine Similarity: 0.3615)
# 857: incin (Cosine Similarity: 0.3615)
# 858: gluc (Cosine Similarity: 0.3614)
# 859: fermented (Cosine Similarity: 0.3614)
# 860: immense (Cosine Similarity: 0.3613)
# 861: cetyl (Cosine Similarity: 0.3612)
# 862: lysed (Cosine Similarity: 0.3612)
# 863: coinc (Cosine Similarity: 0.3612)
# 864: c29 (Cosine Similarity: 0.3612)
# 865: 5h2o (Cosine Similarity: 0.3612)
# 866: antioxid (Cosine Similarity: 0.3612)
# 867: preheat (Cosine Similarity: 0.3612)
# 868: microalgal (Cosine Similarity: 0.3612)
# 869: solvat (Cosine Similarity: 0.3612)
# 870: hyperspectral (Cosine Similarity: 0.3612)
# 871: 361 (Cosine Similarity: 0.3611)
# 872: 18h (Cosine Similarity: 0.3611)
# 873: hts (Cosine Similarity: 0.3611)
# 874: malay (Cosine Similarity: 0.3611)
# 875: pinhole (Cosine Similarity: 0.3611)
# 876: th1 (Cosine Similarity: 0.3610)
# 877: microfluid (Cosine Similarity: 0.3610)
# 878: provincial (Cosine Similarity: 0.3610)
# 879: lysosomal (Cosine Similarity: 0.3610)
# 880: hrtem (Cosine Similarity: 0.3609)
# 881: spintronics (Cosine Similarity: 0.3609)
# 882: tta (Cosine Similarity: 0.3609)
# 883: hydrolytic (Cosine Similarity: 0.3609)
# 884: catalyzes (Cosine Similarity: 0.3609)
# 885: αt (Cosine Similarity: 0.3608)
# 886: li3 (Cosine Similarity: 0.3608)
# 887: zn3 (Cosine Similarity: 0.3608)
# 888: sulfonated (Cosine Similarity: 0.3608)
# 889: condensable (Cosine Similarity: 0.3608)
# 890: so3h (Cosine Similarity: 0.3608)
# 891: spir (Cosine Similarity: 0.3607)
# 892: k2hpo4 (Cosine Similarity: 0.3607)
# 893: pecvd (Cosine Similarity: 0.3607)
# 894: lst (Cosine Similarity: 0.3607)
# 895: tart (Cosine Similarity: 0.3606)
# 896: thiosemicarb (Cosine Similarity: 0.3606)
# 897: pdda (Cosine Similarity: 0.3606)
# 898: accur (Cosine Similarity: 0.3606)
# 899: 063 (Cosine Similarity: 0.3606)
# 900: hexanol (Cosine Similarity: 0.3605)
# 901: demethyl (Cosine Similarity: 0.3605)
# 902: bifur (Cosine Similarity: 0.3605)
# 903: cleav (Cosine Similarity: 0.3605)
# 904: hfd (Cosine Similarity: 0.3604)
# 905: decanted (Cosine Similarity: 0.3604)
# 906: 3400 (Cosine Similarity: 0.3604)
# 907: tdp (Cosine Similarity: 0.3604)
# 908: transports (Cosine Similarity: 0.3604)
# 909: jin (Cosine Similarity: 0.3604)
# 910: glucosamine (Cosine Similarity: 0.3604)
# 911: ρf (Cosine Similarity: 0.3603)
# 912: dibromo (Cosine Similarity: 0.3603)
# 913: cellobi (Cosine Similarity: 0.3603)
# 914: silylation (Cosine Similarity: 0.3603)
# 915: herbal (Cosine Similarity: 0.3602)
# 916: pyrrol (Cosine Similarity: 0.3602)
# 917: peripher (Cosine Similarity: 0.3602)
# 918: argen (Cosine Similarity: 0.3602)
# 919: virul (Cosine Similarity: 0.3601)
# 920: methoxyl (Cosine Similarity: 0.3601)
# 921: desulf (Cosine Similarity: 0.3601)
# 922: recombine (Cosine Similarity: 0.3601)
# 923: tpd (Cosine Similarity: 0.3600)
# 924: crosslinks (Cosine Similarity: 0.3600)
# 925: gsk (Cosine Similarity: 0.3600)
# 926: λex (Cosine Similarity: 0.3600)
# 927: mesoporosity (Cosine Similarity: 0.3600)
# 928: hydrofluor (Cosine Similarity: 0.3600)
# 929: npd (Cosine Similarity: 0.3599)
# 930: ylidene (Cosine Similarity: 0.3599)
# 931: peeled (Cosine Similarity: 0.3599)
# 932: rati (Cosine Similarity: 0.3599)
# 933: monodisper (Cosine Similarity: 0.3599)
# 934: austr (Cosine Similarity: 0.3599)
# 935: polyelectroly (Cosine Similarity: 0.3599)
# 936: valu (Cosine Similarity: 0.3599)
# 937: regul (Cosine Similarity: 0.3598)
# 938: θs (Cosine Similarity: 0.3598)
# 939: flam (Cosine Similarity: 0.3598)
# 940: thy (Cosine Similarity: 0.3598)
# 941: legis (Cosine Similarity: 0.3598)
# 942: 075 (Cosine Similarity: 0.3597)
# 943: promo (Cosine Similarity: 0.3597)
# 944: blooms (Cosine Similarity: 0.3596)
# 945: 622 (Cosine Similarity: 0.3595)
# 946: μj (Cosine Similarity: 0.3595)
# 947: bi2te3 (Cosine Similarity: 0.3595)
# 948: jz (Cosine Similarity: 0.3595)
# 949: electrocatalysis (Cosine Similarity: 0.3595)
# 950: conjug (Cosine Similarity: 0.3594)
# 951: wastewaters (Cosine Similarity: 0.3594)
# 952: wrinkling (Cosine Similarity: 0.3593)
# 953: 3ml (Cosine Similarity: 0.3593)
# 954: guarant (Cosine Similarity: 0.3593)
# 955: pharmacophore (Cosine Similarity: 0.3592)
# 956: 468 (Cosine Similarity: 0.3592)
# 957: cta (Cosine Similarity: 0.3591)
# 958: c24 (Cosine Similarity: 0.3591)
# 959: mfcs (Cosine Similarity: 0.3591)
# 960: indoles (Cosine Similarity: 0.3591)
# 961: hydroxides (Cosine Similarity: 0.3591)
# 962: 035 (Cosine Similarity: 0.3591)
# 963: resorcin (Cosine Similarity: 0.3590)
# 964: bifeo3 (Cosine Similarity: 0.3590)
# 965: phthalocyan (Cosine Similarity: 0.3590)
# 966: retrieve (Cosine Similarity: 0.3590)
# 967: 390 (Cosine Similarity: 0.3590)
# 968: 380 (Cosine Similarity: 0.3589)
# 969: worksh (Cosine Similarity: 0.3589)
# 970: tonnes (Cosine Similarity: 0.3589)
# 971: glycop (Cosine Similarity: 0.3589)
# 972: monso (Cosine Similarity: 0.3589)
# 973: anod (Cosine Similarity: 0.3589)
# 974: hydroform (Cosine Similarity: 0.3589)
# 975: teng (Cosine Similarity: 0.3589)
# 976: 17a (Cosine Similarity: 0.3588)
# 977: dbu (Cosine Similarity: 0.3588)
# 978: si4 (Cosine Similarity: 0.3588)
# 979: 873 (Cosine Similarity: 0.3588)
# 980: raj (Cosine Similarity: 0.3587)
# 981: caroten (Cosine Similarity: 0.3587)
# 982: estu (Cosine Similarity: 0.3587)
# 983: bipyr (Cosine Similarity: 0.3587)
# 984: hospitals (Cosine Similarity: 0.3587)
# 985: c23 (Cosine Similarity: 0.3587)
# 986: colum (Cosine Similarity: 0.3586)
# 987: pemfcs (Cosine Similarity: 0.3586)
# 988: octadecyl (Cosine Similarity: 0.3586)
# 989: hyperbranched (Cosine Similarity: 0.3586)
# 990: trichlor (Cosine Similarity: 0.3586)
# 991: liquefied (Cosine Similarity: 0.3586)
# 992: galactosidase (Cosine Similarity: 0.3586)
# 993: northeastern (Cosine Similarity: 0.3585)
# 994: microbi (Cosine Similarity: 0.3585)
# 995: outperformed (Cosine Similarity: 0.3585)
# 996: pinholes (Cosine Similarity: 0.3584)
# 997: smok (Cosine Similarity: 0.3584)
# 998: bioethanol (Cosine Similarity: 0.3583)
# 999: mediators (Cosine Similarity: 0.3583)
# 1000: unpub (Cosine Similarity: 0.3583)
# 1001: phenolics (Cosine Similarity: 0.3583)
# 1002: tbd (Cosine Similarity: 0.3583)
# 1003: coriol (Cosine Similarity: 0.3583)
# 1004: peop (Cosine Similarity: 0.3582)
# 1005: pbr (Cosine Similarity: 0.3582)
# 1006: sublattices (Cosine Similarity: 0.3582)
# 1007: chloroph (Cosine Similarity: 0.3582)
# 1008: bottleneck (Cosine Similarity: 0.3582)
# 1009: nucleophiles (Cosine Similarity: 0.3582)
# 1010: stakeholders (Cosine Similarity: 0.3582)
# 1011: brill (Cosine Similarity: 0.3581)
# 1012: conglomer (Cosine Similarity: 0.3580)
# 1013: dichlor (Cosine Similarity: 0.3580)
# 1014: azido (Cosine Similarity: 0.3580)
# 1015: substitu (Cosine Similarity: 0.3579)
# 1016: antibio (Cosine Similarity: 0.3579)
# 1017: shortcoming (Cosine Similarity: 0.3579)
# 1018: halogenated (Cosine Similarity: 0.3578)
# 1019: nucleophile (Cosine Similarity: 0.3578)
# 1020: darc (Cosine Similarity: 0.3578)
# 1021: anodes (Cosine Similarity: 0.3577)
# 1022: inundation (Cosine Similarity: 0.3577)
# 1023: photoactivity (Cosine Similarity: 0.3577)
# 1024: noth (Cosine Similarity: 0.3577)
# 1025: 338 (Cosine Similarity: 0.3577)
# 1026: pelagic (Cosine Similarity: 0.3577)
# 1027: tsl (Cosine Similarity: 0.3577)
# 1028: clays (Cosine Similarity: 0.3577)
# 1029: 040 (Cosine Similarity: 0.3577)
# 1030: c30 (Cosine Similarity: 0.3577)
# 1031: analyz (Cosine Similarity: 0.3576)
# 1032: cellulosic (Cosine Similarity: 0.3576)
# 1033: cumbersome (Cosine Similarity: 0.3576)
# 1034: formulate (Cosine Similarity: 0.3576)
# 1035: regi (Cosine Similarity: 0.3576)
# 1036: contemp (Cosine Similarity: 0.3576)
# 1037: hots (Cosine Similarity: 0.3576)
# 1038: mathrm (Cosine Similarity: 0.3575)
# 1039: 372 (Cosine Similarity: 0.3575)
# 1040: nighttime (Cosine Similarity: 0.3575)
# 1041: msns (Cosine Similarity: 0.3575)
# 1042: a7 (Cosine Similarity: 0.3575)
# 1043: c17 (Cosine Similarity: 0.3574)
# 1044: nanoplat (Cosine Similarity: 0.3574)
# 1045: mncl2 (Cosine Similarity: 0.3574)
# 1046: tcf (Cosine Similarity: 0.3573)
# 1047: fron (Cosine Similarity: 0.3573)
# 1048: sunny (Cosine Similarity: 0.3573)
# 1049: mucosa (Cosine Similarity: 0.3573)
# 1050: la0 (Cosine Similarity: 0.3573)
# 1051: dhp (Cosine Similarity: 0.3573)
# 1052: escher (Cosine Similarity: 0.3572)
# 1053: dtg (Cosine Similarity: 0.3572)
# 1054: cyanobacteria (Cosine Similarity: 0.3572)
# 1055: lentiv (Cosine Similarity: 0.3571)
# 1056: oxynitr (Cosine Similarity: 0.3571)
# 1057: 870 (Cosine Similarity: 0.3571)
# 1058: naph (Cosine Similarity: 0.3570)
# 1059: overexpression (Cosine Similarity: 0.3570)
# 1060: gqds (Cosine Similarity: 0.3570)
# 1061: indistinguish (Cosine Similarity: 0.3570)
# 1062: bluesh (Cosine Similarity: 0.3570)
# 1063: 363 (Cosine Similarity: 0.3570)
# 1064: zhao (Cosine Similarity: 0.3570)
# 1065: sdw (Cosine Similarity: 0.3569)
# 1066: emmet (Cosine Similarity: 0.3569)
# 1067: smectite (Cosine Similarity: 0.3569)
# 1068: cmv (Cosine Similarity: 0.3569)
# 1069: particip (Cosine Similarity: 0.3569)
# 1070: eruptive (Cosine Similarity: 0.3568)
# 1071: biotech (Cosine Similarity: 0.3568)
# 1072: anthrac (Cosine Similarity: 0.3568)
# 1073: speek (Cosine Similarity: 0.3568)
# 1074: radiance (Cosine Similarity: 0.3568)
# 1075: leds (Cosine Similarity: 0.3567)
# 1076: 384 (Cosine Similarity: 0.3567)
# 1077: wavel (Cosine Similarity: 0.3567)
# 1078: sang (Cosine Similarity: 0.3567)
# 1079: sapp (Cosine Similarity: 0.3566)
# 1080: chemspider (Cosine Similarity: 0.3566)
# 1081: tsun (Cosine Similarity: 0.3566)
# 1082: leth (Cosine Similarity: 0.3565)
# 1083: lbm (Cosine Similarity: 0.3565)
# 1084: 335 (Cosine Similarity: 0.3565)
# 1085: 217 (Cosine Similarity: 0.3565)
# 1086: 1486 (Cosine Similarity: 0.3565)
# 1087: decolorization (Cosine Similarity: 0.3565)
# 1088: confound (Cosine Similarity: 0.3564)
# 1089: h3o (Cosine Similarity: 0.3564)
# 1090: algan (Cosine Similarity: 0.3564)
# 1091: glutar (Cosine Similarity: 0.3564)
# 1092: λ3 (Cosine Similarity: 0.3564)
# 1093: replic (Cosine Similarity: 0.3564)
# 1094: inaccess (Cosine Similarity: 0.3564)
# 1095: palmi (Cosine Similarity: 0.3564)
# 1096: baked (Cosine Similarity: 0.3563)
# 1097: barr (Cosine Similarity: 0.3563)
# 1098: topmost (Cosine Similarity: 0.3562)
# 1099: ℂ (Cosine Similarity: 0.3562)
# 1100: enh (Cosine Similarity: 0.3562)
# 1101: ferrim (Cosine Similarity: 0.3560)
# 1102: woody (Cosine Similarity: 0.3560)
# 1103: murr (Cosine Similarity: 0.3560)
# 1104: queries (Cosine Similarity: 0.3560)
# 1105: oversh (Cosine Similarity: 0.3559)
# 1106: lcst (Cosine Similarity: 0.3559)
# 1107: 0005 (Cosine Similarity: 0.3559)
# 1108: 7h2o (Cosine Similarity: 0.3559)
# 1109: nmc (Cosine Similarity: 0.3559)
# 1110: sugg (Cosine Similarity: 0.3559)
# 1111: geotechnical (Cosine Similarity: 0.3558)
# 1112: discretize (Cosine Similarity: 0.3558)
# 1113: hydraz (Cosine Similarity: 0.3558)
# 1114: cu1 (Cosine Similarity: 0.3558)
# 1115: phyll (Cosine Similarity: 0.3558)
# 1116: fingerprints (Cosine Similarity: 0.3558)
# 1117: polyplexes (Cosine Similarity: 0.3558)
# 1118: daytime (Cosine Similarity: 0.3557)
# 1119: tiox (Cosine Similarity: 0.3557)
# 1120: mesop (Cosine Similarity: 0.3556)
# 1121: 910 (Cosine Similarity: 0.3556)
# 1122: vaporized (Cosine Similarity: 0.3556)
# 1123: subcut (Cosine Similarity: 0.3556)
# 1124: reliance (Cosine Similarity: 0.3556)
# 1125: burnt (Cosine Similarity: 0.3555)
# 1126: lanes (Cosine Similarity: 0.3555)
# 1127: 690 (Cosine Similarity: 0.3555)
# 1128: membr (Cosine Similarity: 0.3554)
# 1129: 319 (Cosine Similarity: 0.3554)
# 1130: λk (Cosine Similarity: 0.3554)
# 1131: northwestern (Cosine Similarity: 0.3553)
# 1132: publ (Cosine Similarity: 0.3553)
# 1133: xenol (Cosine Similarity: 0.3553)
# 1134: solidus (Cosine Similarity: 0.3553)
# 1135: downreg (Cosine Similarity: 0.3553)
# 1136: thermod (Cosine Similarity: 0.3553)
# 1137: znpc (Cosine Similarity: 0.3552)
# 1138: з (Cosine Similarity: 0.3552)
# 1139: 419 (Cosine Similarity: 0.3552)
# 1140: heter (Cosine Similarity: 0.3552)
# 1141: imprac (Cosine Similarity: 0.3552)
# 1142: turb (Cosine Similarity: 0.3552)
# 1143: li4ti5o12 (Cosine Similarity: 0.3551)
# 1144: cpl (Cosine Similarity: 0.3551)
# 1145: nsclc (Cosine Similarity: 0.3551)
# 1146: nanoph (Cosine Similarity: 0.3551)
# 1147: σxx (Cosine Similarity: 0.3551)
# 1148: desicc (Cosine Similarity: 0.3551)
# 1149: ⅰ (Cosine Similarity: 0.3551)
# 1150: interstiti (Cosine Similarity: 0.3550)
# 1151: subdi (Cosine Similarity: 0.3550)
# 1152: 385 (Cosine Similarity: 0.3550)
# 1153: lithospheric (Cosine Similarity: 0.3549)
# 1154: chlorination (Cosine Similarity: 0.3549)
# 1155: solubilization (Cosine Similarity: 0.3549)
# 1156: polymorphs (Cosine Similarity: 0.3549)
# 1157: bi2wo6 (Cosine Similarity: 0.3549)
# 1158: slurries (Cosine Similarity: 0.3548)
# 1159: c28 (Cosine Similarity: 0.3548)
# 1160: interviews (Cosine Similarity: 0.3548)
# 1161: curv (Cosine Similarity: 0.3547)
# 1162: leukemia (Cosine Similarity: 0.3547)
# 1163: offic (Cosine Similarity: 0.3547)
# 1164: slm (Cosine Similarity: 0.3547)
# 1165: peroxid (Cosine Similarity: 0.3547)
# 1166: 973 (Cosine Similarity: 0.3547)
# 1167: deprotected (Cosine Similarity: 0.3547)
# 1168: absor (Cosine Similarity: 0.3547)
# 1169: integr (Cosine Similarity: 0.3546)
# 1170: photosensi (Cosine Similarity: 0.3546)
# 1171: li0 (Cosine Similarity: 0.3546)
# 1172: 680 (Cosine Similarity: 0.3546)
# 1173: stiffener (Cosine Similarity: 0.3545)
# 1174: decarboxylation (Cosine Similarity: 0.3545)
# 1175: granit (Cosine Similarity: 0.3545)
# 1176: resuspension (Cosine Similarity: 0.3545)
# 1177: zwitter (Cosine Similarity: 0.3545)
# 1178: alkanol (Cosine Similarity: 0.3545)
# 1179: preprocessing (Cosine Similarity: 0.3544)
# 1180: malign (Cosine Similarity: 0.3544)
# 1181: unexp (Cosine Similarity: 0.3544)
# 1182: fwh (Cosine Similarity: 0.3544)
# 1183: 462 (Cosine Similarity: 0.3544)
# 1184: osmosis (Cosine Similarity: 0.3543)
# ...
# 22433: initial (Cosine Similarity: -0.0193)
# 22434: final (Cosine Similarity: -0.0193)
# 22435: applied (Cosine Similarity: -0.0196)
# 22436: ge (Cosine Similarity: -0.0196)
# 22437: may (Cosine Similarity: -0.0196)
# 22438: global (Cosine Similarity: -0.0197)
# 22439: liquid (Cosine Similarity: -0.0199)
# 22440: sp (Cosine Similarity: -0.0200)
# 22441: scale (Cosine Similarity: -0.0202)
# 22442: ru (Cosine Similarity: -0.0203)
# 22443: result (Cosine Similarity: -0.0203)
# 22444: between (Cosine Similarity: -0.0204)
# 22445: glass (Cosine Similarity: -0.0204)
# 22446: structural (Cosine Similarity: -0.0208)
# 22447: part (Cosine Similarity: -0.0210)
# 22448: transfer (Cosine Similarity: -0.0211)
# 22449: error (Cosine Similarity: -0.0213)
# 22450: values (Cosine Similarity: -0.0213)
# 22451: characteristic (Cosine Similarity: -0.0219)
# 22452: end (Cosine Similarity: -0.0219)
# 22453: oxygen (Cosine Similarity: -0.0223)
# 22454: expected (Cosine Similarity: -0.0223)
# 22455: position (Cosine Similarity: -0.0223)
# 22456: scan (Cosine Similarity: -0.0224)
# 22457: parallel (Cosine Similarity: -0.0225)
# 22458: per (Cosine Similarity: -0.0226)
# 22459: 50 (Cosine Similarity: -0.0229)
# 22460: generally (Cosine Similarity: -0.0230)
# 22461: average (Cosine Similarity: -0.0231)
# 22462: co2 (Cosine Similarity: -0.0237)
# 22463: active (Cosine Similarity: -0.0241)
# 22464: working (Cosine Similarity: -0.0241)
# 22465: effects (Cosine Similarity: -0.0242)
# 22466: determined (Cosine Similarity: -0.0242)
# 22467: β (Cosine Similarity: -0.0244)
# 22468: component (Cosine Similarity: -0.0248)
# 22469: elastic (Cosine Similarity: -0.0249)
# 22470: term (Cosine Similarity: -0.0249)
# 22471: ab (Cosine Similarity: -0.0249)
# 22472: experiment (Cosine Similarity: -0.0251)
# 22473: element (Cosine Similarity: -0.0252)
# 22474: net (Cosine Similarity: -0.0253)
# 22475: shift (Cosine Similarity: -0.0253)
# 22476: good (Cosine Similarity: -0.0253)
# 22477: ms (Cosine Similarity: -0.0253)
# 22478: base (Cosine Similarity: -0.0256)
# 22479: strain (Cosine Similarity: -0.0256)
# 22480: either (Cosine Similarity: -0.0257)
# 22481: max (Cosine Similarity: -0.0257)
# 22482: around (Cosine Similarity: -0.0258)
# 22483: calculated (Cosine Similarity: -0.0260)
# 22484: mixed (Cosine Similarity: -0.0261)
# 22485: properties (Cosine Similarity: -0.0262)
# 22486: pattern (Cosine Similarity: -0.0263)
# 22487: off (Cosine Similarity: -0.0264)
# 22488: rod (Cosine Similarity: -0.0268)
# 22489: γ (Cosine Similarity: -0.0270)
# 22490: direct (Cosine Similarity: -0.0272)
# 22491: combined (Cosine Similarity: -0.0273)
# 22492: when (Cosine Similarity: -0.0273)
# 22493: transition (Cosine Similarity: -0.0275)
# 22494: large (Cosine Similarity: -0.0277)
# 22495: particle (Cosine Similarity: -0.0279)
# 22496: displacement (Cosine Similarity: -0.0280)
# 22497: plasma (Cosine Similarity: -0.0281)
# 22498: content (Cosine Similarity: -0.0284)
# 22499: 15 (Cosine Similarity: -0.0286)
# 22500: configuration (Cosine Similarity: -0.0289)
# 22501: concrete (Cosine Similarity: -0.0293)
# 22502: ch (Cosine Similarity: -0.0294)
# 22503: na (Cosine Similarity: -0.0296)
# 22504: t (Cosine Similarity: -0.0297)
# 22505: ps (Cosine Similarity: -0.0301)
# 22506: modified (Cosine Similarity: -0.0304)
# 22507: w (Cosine Similarity: -0.0307)
# 22508: 7 (Cosine Similarity: -0.0307)
# 22509: its (Cosine Similarity: -0.0307)
# 22510: quality (Cosine Similarity: -0.0307)
# 22511: ring (Cosine Similarity: -0.0308)
# 22512: effective (Cosine Similarity: -0.0311)
# 22513: protein (Cosine Similarity: -0.0312)
# 22514: along (Cosine Similarity: -0.0312)
# 22515: condition (Cosine Similarity: -0.0312)
# 22516: density (Cosine Similarity: -0.0313)
# 22517: channel (Cosine Similarity: -0.0316)
# 22518: same (Cosine Similarity: -0.0318)
# 22519: half (Cosine Similarity: -0.0320)
# 22520: zone (Cosine Similarity: -0.0321)
# 22521: δ (Cosine Similarity: -0.0323)
# 22522: probe (Cosine Similarity: -0.0323)
# 22523: available (Cosine Similarity: -0.0324)
# 22524: possible (Cosine Similarity: -0.0326)
# 22525: however (Cosine Similarity: -0.0326)
# 22526: measure (Cosine Similarity: -0.0328)
# 22527: conditions (Cosine Similarity: -0.0333)
# 22528: special (Cosine Similarity: -0.0335)
# 22529: design (Cosine Similarity: -0.0335)
# 22530: study (Cosine Similarity: -0.0338)
# 22531: short (Cosine Similarity: -0.0341)
# 22532: measurements (Cosine Similarity: -0.0343)
# 22533: fc (Cosine Similarity: -0.0344)
# 22534: within (Cosine Similarity: -0.0348)
# 22535: line (Cosine Similarity: -0.0349)
# 22536: if (Cosine Similarity: -0.0352)
# 22537: thus (Cosine Similarity: -0.0352)
# 22538: being (Cosine Similarity: -0.0353)
# 22539: up (Cosine Similarity: -0.0355)
# 22540: detection (Cosine Similarity: -0.0356)
# 22541: he (Cosine Similarity: -0.0357)
# 22542: j (Cosine Similarity: -0.0358)
# 22543: bound (Cosine Similarity: -0.0358)
# 22544: center (Cosine Similarity: -0.0359)
# 22545: four (Cosine Similarity: -0.0359)
# 22546: deformation (Cosine Similarity: -0.0360)
# 22547: temperature (Cosine Similarity: -0.0365)
# 22548: cells (Cosine Similarity: -0.0365)
# 22549: produced (Cosine Similarity: -0.0373)
# 22550: current (Cosine Similarity: -0.0378)
# 22551: particular (Cosine Similarity: -0.0381)
# 22552: cut (Cosine Similarity: -0.0383)
# 22553: out (Cosine Similarity: -0.0386)
# 22554: bar (Cosine Similarity: -0.0389)
# 22555: clear (Cosine Similarity: -0.0389)
# 22556: bond (Cosine Similarity: -0.0394)
# 22557: these (Cosine Similarity: -0.0399)
# 22558: internal (Cosine Similarity: -0.0412)
# 22559: y (Cosine Similarity: -0.0414)
# 22560: critical (Cosine Similarity: -0.0419)
# 22561: loss (Cosine Similarity: -0.0420)
# 22562: just (Cosine Similarity: -0.0421)
# 22563: stable (Cosine Similarity: -0.0421)
# 22564: most (Cosine Similarity: -0.0422)
# 22565: measurement (Cosine Similarity: -0.0432)
# 22566: pe (Cosine Similarity: -0.0434)
# 22567: groups (Cosine Similarity: -0.0435)
# 22568: resulting (Cosine Similarity: -0.0439)
# 22569: required (Cosine Similarity: -0.0439)
# 22570: 100 (Cosine Similarity: -0.0439)
# 22571: light (Cosine Similarity: -0.0439)
# 22572: force (Cosine Similarity: -0.0441)
# 22573: size (Cosine Similarity: -0.0441)
# 22574: ion (Cosine Similarity: -0.0442)
# 22575: formed (Cosine Similarity: -0.0444)
# 22576: pure (Cosine Similarity: -0.0444)
# 22577: production (Cosine Similarity: -0.0445)
# 22578: fine (Cosine Similarity: -0.0448)
# 22579: addition (Cosine Similarity: -0.0453)
# 22580: based (Cosine Similarity: -0.0453)
# 22581: order (Cosine Similarity: -0.0454)
# 22582: common (Cosine Similarity: -0.0455)
# 22583: z (Cosine Similarity: -0.0458)
# 22584: mo (Cosine Similarity: -0.0459)
# 22585: g (Cosine Similarity: -0.0461)
# 22586: induced (Cosine Similarity: -0.0462)
# 22587: second (Cosine Similarity: -0.0462)
# 22588: here (Cosine Similarity: -0.0462)
# 22589: impact (Cosine Similarity: -0.0462)
# 22590: domain (Cosine Similarity: -0.0464)
# 22591: fe (Cosine Similarity: -0.0469)
# 22592: reduction (Cosine Similarity: -0.0478)
# 22593: field (Cosine Similarity: -0.0481)
# 22594: h (Cosine Similarity: -0.0489)
# 22595: now (Cosine Similarity: -0.0490)
# 22596: real (Cosine Similarity: -0.0491)
# 22597: sample (Cosine Similarity: -0.0498)
# 22598: ii (Cosine Similarity: -0.0498)
# 22599: added (Cosine Similarity: -0.0506)
# 22600: changes (Cosine Similarity: -0.0509)
# 22601: pa (Cosine Similarity: -0.0510)
# 22602: phase (Cosine Similarity: -0.0511)
# 22603: similar (Cosine Similarity: -0.0511)
# 22604: equilibrium (Cosine Similarity: -0.0515)
# 22605: distribution (Cosine Similarity: -0.0520)
# 22606: length (Cosine Similarity: -0.0522)
# 22607: composite (Cosine Similarity: -0.0526)
# 22608: like (Cosine Similarity: -0.0528)
# 22609: concentration (Cosine Similarity: -0.0532)
# 22610: response (Cosine Similarity: -0.0535)
# 22611: overall (Cosine Similarity: -0.0536)
# 22612: some (Cosine Similarity: -0.0536)
# 22613: associated (Cosine Similarity: -0.0541)
# 22614: equivalent (Cosine Similarity: -0.0542)
# 22615: metal (Cosine Similarity: -0.0546)
# 22616: gap (Cosine Similarity: -0.0546)
# 22617: gas (Cosine Similarity: -0.0547)
# 22618: x (Cosine Similarity: -0.0547)
# 22619: experimental (Cosine Similarity: -0.0548)
# 22620: we (Cosine Similarity: -0.0549)
# 22621: si (Cosine Similarity: -0.0552)
# 22622: number (Cosine Similarity: -0.0552)
# 22623: below (Cosine Similarity: -0.0552)
# 22624: α (Cosine Similarity: -0.0558)
# 22625: u (Cosine Similarity: -0.0564)
# 22626: non (Cosine Similarity: -0.0566)
# 22627: was (Cosine Similarity: -0.0573)
# 22628: ac (Cosine Similarity: -0.0576)
# 22629: well (Cosine Similarity: -0.0578)
# 22630: but (Cosine Similarity: -0.0582)
# 22631: open (Cosine Similarity: -0.0591)
# 22632: yield (Cosine Similarity: -0.0593)
# 22633: lower (Cosine Similarity: -0.0595)
# 22634: following (Cosine Similarity: -0.0595)
# 22635: 20 (Cosine Similarity: -0.0598)
# 22636: value (Cosine Similarity: -0.0600)
# 22637: product (Cosine Similarity: -0.0600)
# 22638: simple (Cosine Similarity: -0.0602)
# 22639: unit (Cosine Similarity: -0.0605)
# 22640: other (Cosine Similarity: -0.0605)
# 22641: shape (Cosine Similarity: -0.0605)
# 22642: three (Cosine Similarity: -0.0605)
# 22643: 9 (Cosine Similarity: -0.0614)
# 22644: q (Cosine Similarity: -0.0615)
# 22645: after (Cosine Similarity: -0.0626)
# 22646: mean (Cosine Similarity: -0.0626)
# 22647: local (Cosine Similarity: -0.0634)
# 22648: above (Cosine Similarity: -0.0640)
# 22649: polymer (Cosine Similarity: -0.0642)
# 22650: normal (Cosine Similarity: -0.0646)
# 22651: measured (Cosine Similarity: -0.0649)
# 22652: reduced (Cosine Similarity: -0.0650)
# 22653: individual (Cosine Similarity: -0.0651)
# 22654: band (Cosine Similarity: -0.0651)
# 22655: near (Cosine Similarity: -0.0652)
# 22656: systems (Cosine Similarity: -0.0655)
# 22657: compound (Cosine Similarity: -0.0656)
# 22658: process (Cosine Similarity: -0.0660)
# 22659: cs (Cosine Similarity: -0.0663)
# 22660: 8 (Cosine Similarity: -0.0663)
# 22661: such (Cosine Similarity: -0.0674)
# 22662: ratio (Cosine Similarity: -0.0675)
# 22663: geometry (Cosine Similarity: -0.0676)
# 22664: matrix (Cosine Similarity: -0.0678)
# 22665: mass (Cosine Similarity: -0.0680)
# 22666: further (Cosine Similarity: -0.0681)
# 22667: related (Cosine Similarity: -0.0685)
# 22668: cluster (Cosine Similarity: -0.0689)
# 22669: long (Cosine Similarity: -0.0690)
# 22670: re (Cosine Similarity: -0.0696)
# 22671: function (Cosine Similarity: -0.0697)
# 22672: difference (Cosine Similarity: -0.0705)
# 22673: power (Cosine Similarity: -0.0705)
# 22674: see (Cosine Similarity: -0.0710)
# 22675: double (Cosine Similarity: -0.0713)
# 22676: more (Cosine Similarity: -0.0720)
# 22677: crystal (Cosine Similarity: -0.0721)
# 22678: linear (Cosine Similarity: -0.0722)
# 22679: reaction (Cosine Similarity: -0.0736)
# 22680: each (Cosine Similarity: -0.0741)
# 22681: natural (Cosine Similarity: -0.0744)
# 22682: have (Cosine Similarity: -0.0747)
# 22683: 6 (Cosine Similarity: -0.0748)
# 22684: results (Cosine Similarity: -0.0748)
# 22685: o (Cosine Similarity: -0.0752)
# 22686: even (Cosine Similarity: -0.0753)
# 22687: use (Cosine Similarity: -0.0756)
# 22688: range (Cosine Similarity: -0.0766)
# 22689: so (Cosine Similarity: -0.0769)
# 22690: ca (Cosine Similarity: -0.0774)
# 22691: activity (Cosine Similarity: -0.0780)
# 22692: are (Cosine Similarity: -0.0783)
# 22693: air (Cosine Similarity: -0.0786)
# 22694: min (Cosine Similarity: -0.0799)
# 22695: state (Cosine Similarity: -0.0803)
# 22696: de (Cosine Similarity: -0.0804)
# 22697: type (Cosine Similarity: -0.0808)
# 22698: method (Cosine Similarity: -0.0809)
# 22699: about (Cosine Similarity: -0.0815)
# 22700: low (Cosine Similarity: -0.0815)
# 22701: it (Cosine Similarity: -0.0818)
# 22702: cross (Cosine Similarity: -0.0828)
# 22703: found (Cosine Similarity: -0.0830)
# 22704: n (Cosine Similarity: -0.0832)
# 22705: less (Cosine Similarity: -0.0835)
# 22706: total (Cosine Similarity: -0.0840)
# 22707: 0 (Cosine Similarity: -0.0846)
# 22708: f (Cosine Similarity: -0.0850)
# 22709: general (Cosine Similarity: -0.0852)
# 22710: constant (Cosine Similarity: -0.0852)
# 22711: this (Cosine Similarity: -0.0863)
# 22712: r (Cosine Similarity: -0.0872)
# 22713: m (Cosine Similarity: -0.0873)
# 22714: then (Cosine Similarity: -0.0878)
# 22715: observed (Cosine Similarity: -0.0889)
# 22716: obtained (Cosine Similarity: -0.0894)
# 22717: volume (Cosine Similarity: -0.0908)
# 22718: 12 (Cosine Similarity: -0.0920)
# 22719: from (Cosine Similarity: -0.0923)
# 22720: frequency (Cosine Similarity: -0.0930)
# 22721: formation (Cosine Similarity: -0.0937)
# 22722: v (Cosine Similarity: -0.0941)
# 22723: effect (Cosine Similarity: -0.0951)
# 22724: area (Cosine Similarity: -0.0952)
# 22725: be (Cosine Similarity: -0.0957)
# 22726: material (Cosine Similarity: -0.0960)
# 22727: given (Cosine Similarity: -0.0972)
# 22728: not (Cosine Similarity: -0.0979)
# 22729: work (Cosine Similarity: -0.0981)
# 22730: present (Cosine Similarity: -0.0983)
# 22731: potential (Cosine Similarity: -0.0985)
# 22732: rate (Cosine Similarity: -0.1005)
# 22733: has (Cosine Similarity: -0.1011)
# 22734: first (Cosine Similarity: -0.1012)
# 22735: mode (Cosine Similarity: -0.1014)
# 22736: used (Cosine Similarity: -0.1018)
# 22737: point (Cosine Similarity: -0.1019)
# 22738: i (Cosine Similarity: -0.1028)
# 22739: standard (Cosine Similarity: -0.1031)
# 22740: b (Cosine Similarity: -0.1036)
# 22741: p (Cosine Similarity: -0.1038)
# 22742: under (Cosine Similarity: -0.1044)
# 22743: ar (Cosine Similarity: -0.1046)
# 22744: relative (Cosine Similarity: -0.1049)
# 22745: signal (Cosine Similarity: -0.1051)
# 22746: different (Cosine Similarity: -0.1069)
# 22747: corresponding (Cosine Similarity: -0.1074)
# 22748: cell (Cosine Similarity: -0.1076)
# 22749: an (Cosine Similarity: -0.1087)
# 22750: 5 (Cosine Similarity: -0.1089)
# 22751: single (Cosine Similarity: -0.1091)
# 22752: structure (Cosine Similarity: -0.1102)
# 22753: can (Cosine Similarity: -0.1106)
# 22754: both (Cosine Similarity: -0.1109)
# 22755: d (Cosine Similarity: -0.1113)
# 22756: solution (Cosine Similarity: -0.1119)
# 22757: time (Cosine Similarity: -0.1127)
# 22758: small (Cosine Similarity: -0.1130)
# 22759: which (Cosine Similarity: -0.1136)
# 22760: control (Cosine Similarity: -0.1141)
# 22761: 4 (Cosine Similarity: -0.1148)
# 22762: dynamic (Cosine Similarity: -0.1153)
# 22763: complex (Cosine Similarity: -0.1157)
# 22764: specific (Cosine Similarity: -0.1161)
# 22765: level (Cosine Similarity: -0.1172)
# 22766: over (Cosine Similarity: -0.1177)
# 22767: all (Cosine Similarity: -0.1192)
# 22768: using (Cosine Similarity: -0.1210)
# 22769: new (Cosine Similarity: -0.1214)
# 22770: flow (Cosine Similarity: -0.1240)
# 22771: co (Cosine Similarity: -0.1249)
# 22772: energy (Cosine Similarity: -0.1274)
# 22773: water (Cosine Similarity: -0.1281)
# 22774: set (Cosine Similarity: -0.1288)
# 22775: one (Cosine Similarity: -0.1289)
# 22776: k (Cosine Similarity: -0.1302)
# 22777: also (Cosine Similarity: -0.1314)
# 22778: change (Cosine Similarity: -0.1322)
# 22779: 3 (Cosine Similarity: -0.1330)
# 22780: analysis (Cosine Similarity: -0.1345)
# 22781: two (Cosine Similarity: -0.1359)
# 22782: that (Cosine Similarity: -0.1387)
# 22783: carbon (Cosine Similarity: -0.1401)
# 22784: 10 (Cosine Similarity: -0.1419)
# 22785: data (Cosine Similarity: -0.1435)
# 22786: group (Cosine Similarity: -0.1461)
# 22787: test (Cosine Similarity: -0.1482)
# 22788: model (Cosine Similarity: -0.1488)
# 22789: only (Cosine Similarity: -0.1519)
# 22790: s (Cosine Similarity: -0.1520)
# 22791: e (Cosine Similarity: -0.1558)
# 22792: or (Cosine Similarity: -0.1571)
# 22793: system (Cosine Similarity: -0.1573)
# 22794: at (Cosine Similarity: -0.1579)
# 22795: free (Cosine Similarity: -0.1621)
# 22796: form (Cosine Similarity: -0.1641)
# 22797: no (Cosine Similarity: -0.1642)
# 22798: surface (Cosine Similarity: -0.1663)
# 22799: by (Cosine Similarity: -0.1688)
# 22800: on (Cosine Similarity: -0.1787)
# 22801: is (Cosine Similarity: -0.1847)
# 22802: with (Cosine Similarity: -0.1878)
# 22803: 2 (Cosine Similarity: -0.1908)
# 22804: for (Cosine Similarity: -0.1913)
# 22805: as (Cosine Similarity: -0.1967)
# 22806: 1 (Cosine Similarity: -0.1999)
# 22807: to (Cosine Similarity: -0.2003)
# 22808: c (Cosine Similarity: -0.2066)
# 22809: of (Cosine Similarity: -0.2595)
# 22810: and (Cosine Similarity: -0.2656)
# 22811: a (Cosine Similarity: -0.2732)
# 22812: in (Cosine Similarity: -0.2925)
# 22813: the (Cosine Similarity: -0.2927)
